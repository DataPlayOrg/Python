# %%
# Function to print in larger font
def print_large(text):
    print(
        "\033[1;37;40m" + str(text) + "\033[0m"
    )  # Using ANSI escape codes for larger font size, white text, and black background

# %% [markdown]
# # The Never-ending To-Do List ->  List

# %%
# Creation
print_large("Creation:")
print("Mahima began by creating a list of songs for the wedding ceremony:")
input("Ready to see the code? (Press Enter to continue)")
print_large('\n\nsongs_list = ["Here Comes the Bride", "Canon in D", "A Thousand Years", "Marry You"]\n\n')
songs_list = ["Here Comes the Bride", "Canon in D", "A Thousand Years", "Marry You"]
input("Want to go to next task? (Press Enter to continue)")

# Checking Existence
print_large("Checking Existence:")
print("Her aunt asked if 'Perfect' by Ed Sheeran was on the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large('\n\nis_exist = "Perfect" in songs_list\n\n')
is_exist = "Perfect" in songs_list
input("Want to go to next task? (Press Enter to continue)")

# Finding the Item
print_large("Finding the Item:")
print("Her uncle thought 'A Thousand Years' wasn't added to the playlist, so she decided to check its position.")
input("Ready to see the code? (Press Enter to continue)")
print_large('\n\nindex = songs_list.index("A Thousand Years")\n\n')
index = songs_list.index("A Thousand Years")
input("Want to go to next task? (Press Enter to continue)")

# Adding Songs
print_large("Adding Songs:")
print("Her mother asked her to add a new song 'Perfect' by Ed Sheeran.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.append('Perfect')\n\n")
songs_list.append("Perfect")
input("Want to go to next task? (Press Enter to continue)")

# Adding at Specific Spots
print_large("Adding at Specific Spots:")
print("Her mother suggested adding 'Here Comes the Bride' at the start of the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.insert(0, 'Here Comes the Bride')\n\n")
songs_list.insert(0, "Here Comes the Bride")
input("Want to go to next task? (Press Enter to continue)")

# Removing Songs
print_large("Removing Songs:")
print("Her brother suggested removing 'Canon in D' from the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.remove('Canon in D')\n\n")
songs_list.remove("Canon in D")
input("Want to go to next task? (Press Enter to continue)")

# Modifying Elements
print_large("Modifying Elements:")
print("She realized she accidentally added 'Perfect' twice, so she decided to modify it.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list[songs_list.index('Perfect')] = 'Perfect (Acoustic)'\n\n")
songs_list[songs_list.index("Perfect")] = "Perfect (Acoustic)"
input("Want to go to next task? (Press Enter to continue)")

# Slicing
print_large("Slicing:")
print("Her sister asked for every alternate song on the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nevery_other_song = songs_list[0:5:2]\n\n")
every_other_song = songs_list[0:5:2]
input("Want to go to next task? (Press Enter to continue)")

# Sorting
print_large("Sorting:")
print("Being organized, she decided to sort the playlist alphabetically.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.sort()\n\n")
songs_list.sort()
input("Want to go to next task? (Press Enter to continue)")

# Length
print_large("Length:")
print("She wondered how many songs were on the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("num_songs = len(songs_list)\n\n")
num_songs = len(songs_list)
input("Want to go to next task? (Press Enter to continue)")

# Occurrence
print_large("Occurrence:")
print("She wanted to know if the song 'A Thousand Years' appeared more than once.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nnum_occurrences = songs_list.count('A Thousand Years')\n\n")
num_occurrences = songs_list.count("A Thousand Years")
input("Want to go to next task? (Press Enter to continue)")

# Extending the Playlist
print_large("Extending Playlist -> Modifies original list:")
print("Her friend Richa sent her some more songs for the playlist: ['Shallow', 'All of Me'].")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.extend(['Shallow', 'All of Me'])\n\n")
songs_list.extend(["Shallow", "All of Me"])
input("Want to go to next task? (Press Enter to continue)")

# Concatenation
print_large("Concatenation -> Resulting in a new list:")
print("Her friend sent her some additional songs, but she wanted to create a new playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nnew_playlist = songs_list + ['Shallow', 'All of Me']\n\n")
new_playlist = songs_list + ["Shallow", "All of Me"]
input("Want to go to next task? (Press Enter to continue)")

# Clearing all elements
print_large("Clearing all elements:")
print("After the wedding, she decided to clear the playlist.")
input("Ready to see the code? (Press Enter to continue)")
print_large("\n\nsongs_list.clear()\n\n")
songs_list.clear()
print("\n########End of task########\n")
# Out:
# Creation:
# Mahima began by creating a list of songs for the wedding ceremony:
# Ready to see the code? (Press Enter to continue)
#
#
# songs_list = ["Here Comes the Bride", "Canon in D", "A Thousand Years", "Marry You"]
#
#
# Want to go to next task? (Press Enter to continue)
# Checking Existence:
# Her aunt asked if 'Perfect' by Ed Sheeran was on the playlist.
# Ready to see the code? (Press Enter to continue)
#
#
# is_exist = "Perfect" in songs_list
#
#
# Want to go to next task? (Press Enter to continue)
# Finding the Item:
# Her uncle thought 'A Thousand Years' wasn't added to the playlist, so she decided to check its position.
# Ready to see the code? (Press Enter to continue)
#
#
# index = songs_list.index("A Thousand Years")
#
#
# Want to go to next task? (Press Enter to continue)
# Adding Songs:
# Her mother asked her to add a new song 'Perfect' by Ed Sheeran.
# Ready to see the code? (Press Enter to continue)
#
#
# songs_list.append('Perfect')
#
#
# ...

# %% [markdown]
# # Vendor Information -> Dictionary

# %%
# Creation:
print_large("Creation")
print('Mahima started with a dictionary {} containing flowers and wedding_rings vendor number.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nvendor_details = {"flowers":"1240-3343345","wedding_rings":"4787-5636"}\n\n')
vendor_details = {"flowers": "1240-3343345", "wedding_rings": "4787-5636"}
input("Want to go to next task? (Press Enter to continue)")

# Checking for a key:
print_large("Checking for a key:")
print('She thought to find if the caterer\'s details are in the vendor details.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\n"food" in vendor_details.keys()\n\n')
is_food = "food" in vendor_details.keys()
input("Want to go to next task? (Press Enter to continue)")

# Checking for a value:
print_large("Checking for a value:")
print('She also wanted to verify if a phone number was present in the vendor details.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\n"123-56578" in vendor_details.values()\n\n')
is_phone_number = "123-56578" in vendor_details.values()
input("Want to go to next task? (Press Enter to continue)")

# Adding Vendor a new key value pair:
print_large("Adding Vendor a new key value pair:")
print('Her mother finally secured a caterer - Simply Delicious! She added the caterer\'s details as a new key-value pair.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nvendor_details["food"] = "123-456-7890"\n\n')
vendor_details["food"] = "123-456-7890"
input("Want to go to next task? (Press Enter to continue)")

# Removing an entry:
print_large("Removing an entry:")
print('She found the behavior of the food caterer is not good so she wanted to delete the entry.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\ndel vendor_details["food"]\n\n')
del vendor_details["food"]
input("Want to go to next task? (Press Enter to continue)")

# Modifying Elements:
print_large("Modifying Elements:")
print('She realized she accidentally wrote the wrong wedding ring contractor number.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nvendor_details["wedding_rings"] = "4787-4636"\n\n')
vendor_details["wedding_rings"] = "4787-4636"
input("Want to go to next task? (Press Enter to continue)")

# Length:
print_large("Length:")
print('She wondered how many vendor details are there?')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nlen(vendor_details)\n\n')
len(vendor_details)
input("Press Enter to continue...")

# Extending
print_large("Extending Dictionary -> Modifies original dictionary which is written first:")
print('Her friend Richa sent her a dictionary of additional vendors extra_vendor_details = {"Hair Stylist": "123-368548"}.')
extra_vendor_details = {"Hair Stylist": "123-368548"}
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nvendor_details.update(extra_vendor_details)\n\n')
vendor_details.update(extra_vendor_details)
input("Want to go to next task? (Press Enter to continue)")

# Concatenation
print_large("Concatenation -> Resulting in a new dictionary:")
print('Her friend Richa sent her a dictionary of additional vendors extra_vendor_details = {"Hair Stylist": "123-368548"}.')
extra_vendor_details = {"Hair Stylist": "123-368548"}
input("Ready to see code? (Press Enter to continue)")
print_large('\n\n\033[91mWe can\'t do this/ Not allowed -> \'vendor_details + extra_vendor_details\'\033[0m')
print_large('\033[92mInstead we do this and create a new dict : combined_vendor_details = {**vendor_details, **extra_vendor_details}\033[0m\n\n')
combined_vendor_details = {**vendor_details, **extra_vendor_details}
input("Want to go to next task? (Press Enter to continue)")

# Clearing all elements:
print_large("Clearing all elements:")
print('She decided to empty the dictionary and make a fresh dictionary as her mother did not like any contacts.')
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nvendor_details.clear()\n\n')
vendor_details.clear()
print("\n########End of task########\n")
# Out:
# Creation
# Mahima started with a dictionary {} containing flowers and wedding_rings vendor number.
# Ready to see code? (Press Enter to continue)
#
#
# vendor_details = {"flowers":"1240-3343345","wedding_rings":"4787-5636"}
#
#
# Want to go to next task? (Press Enter to continue)
# Checking for a key:
# She thought to find if the caterer's details are in the vendor details.
# Ready to see code? (Press Enter to continue)
#
#
# "food" in vendor_details.keys()
#
#
# Want to go to next task? (Press Enter to continue)
# Checking for a value:
# She also wanted to verify if a phone number was present in the vendor details.
# Ready to see code? (Press Enter to continue)
#
#
# "123-56578" in vendor_details.values()
#
#
# Want to go to next task? (Press Enter to continue)
# Adding Vendor a new key value pair:
# Her mother finally secured a caterer - Simply Delicious! She added the caterer's details as a new key-value pair.
# Ready to see code? (Press Enter to continue)
#
#
# ...

# %% [markdown]
# # Fun part

# %%
## Note :
dict1 = {"a": 1, "b": 2}
dict2 = {"b": 3, "c": 4}
print(
    "If dict1 = {'a': 1, 'b': 2} , dict2 = {'b': 3, 'c': 4} then {**dict1, **dict2} == {**dict2, **dict1} ?"
)

input("Ready to see result? (Press Enter to continue)")

print("{**dict1, **dict2} :", {**dict1, **dict2})
print("{**dict2, **dict1}:", {**dict2, **dict1})
print({**dict1, **dict2} == {**dict2, **dict1})

# %% [markdown]
# # Wedding Roles -> Tuples

# %%
# Creation
print_large("Creation:")
print("Mahima started assigning roles to Sarika and Ritika for wedding tasks:")
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nbridesmaid_role = ('Sarika', 'Ritika')\n\n")
bridesmaid_role = ("Sarika", "Ritika")
input("Want to go to next task? (Press Enter to continue)")


# Finding the index
print_large("Finding the girl:")
print(
    "Her absent-minded aunt kept asking again and again about Sarika being a bridesmaid. So she decided to tell her with position."
)
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nbridesmaid_role.index('Sarika')\n\n")
bridesmaid_index = bridesmaid_role.index("Sarika")
input("Want to go to next task? (Press Enter to continue)")


# Checking Existence
print_large("Checking Existence:")
print("Her absent-minded uncle asked her if she has added Ritika as bridesmaid")
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nis_bridesmaid = 'Ritika' in bridesmaid_role\n\n")
is_bridesmaid = "Ritika" in bridesmaid_role
input("Want to go to next task? (Press Enter to continue)")


# Adding Tasks
print_large("Adding Tasks:")
print("Her mother asked her to add 'Monika' to bridesmaid_role.")
input("Ready to see code? (Press Enter to continue)")
print_large(
    "\n\033[91mShe tried finding an inbuilt function to update the tuple but could not find. So she did a jugaad and created a new tuple variable.\033[0m"
)
print_large("\nnew_bridesmaid_role = bridesmaid_role + ('Monika',)\n\n")
new_bridesmaid_role = bridesmaid_role + ("Monika",)
input("Want to go to next task? (Press Enter to continue)")


# Slicing
print_large("Slicing:")
print(
    "She decided to assign some tasks to the 2nd and 3rd bridesmaid as Sarika was overburdened."
)
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nnew_assignees = new_bridesmaid_role[1:3]\n\n")
new_assignees = new_bridesmaid_role[1:3]
input("Want to go to next task? (Press Enter to continue)")


# Length
print_large("Length:")
print("She wondered how many bridesmaids are there")
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nlen(new_bridesmaid_role)\n\n")
bridesmaid_role_length = len(new_bridesmaid_role)
input("Want to go to next task? (Press Enter to continue)")


# Occurrence
print_large("Occurrence:")
print("She wanted to know if Sarika appeared multiple times in the tuple.")
input("Ready to see code? (Press Enter to continue)")
print_large("\n\nnum_times = bridesmaid_role.count('Sarika')\n\n")
num_times = new_bridesmaid_role.count("Sarika")
input("Want to go to next task? (Press Enter to continue)")


# Concatenation
print_large("Concatenation -> Resulting in a new tuple:")
print(
    "She wanted to see all the roles for both bridesmaids and groomsmen to distribute the dress code."
)
input("Ready to see code? (Press Enter to continue)")
print_large("\n\ncombined_roles = bridesmaid_role + groomsman_role\n\n")
groomsman_role = ("Ram", "Shyam")
combined_roles = new_bridesmaid_role + groomsman_role
print("\n########End of task########\n")
# Out:
# Creation:
# Mahima started assigning roles to Sarika and Ritika for wedding tasks:
# Ready to see code? (Press Enter to continue)
#
#
# bridesmaid_role = ('Sarika', 'Ritika')
#
#
# Want to go to next task? (Press Enter to continue)
# Finding the girl:
# Her absent-minded aunt kept asking again and again about Sarika being a bridesmaid. So she decided to tell her with position.
# Ready to see code? (Press Enter to continue)
#
#
# bridesmaid_role.index('Sarika')
#
#
# Want to go to next task? (Press Enter to continue)
# Checking Existence:
# Her absent-minded uncle asked her if she has added Ritika as bridesmaid
# Ready to see code? (Press Enter to continue)
#
#
# is_bridesmaid = 'Ritika' in bridesmaid_role
#
#
# Want to go to next task? (Press Enter to continue)
# Adding Tasks:
# Her mother asked her to add 'Monika' to bridesmaid_role.
# Ready to see code? (Press Enter to continue)
#
# ...

# %% [markdown]
# #  The Unique Guest List:  Set

# %%
# Creation:
print_large("Creation:")
print("Mahima started with a set {} containing her friends Sarika, Divya, Kavita")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nguest_set = {"Sarika", "Divya","Kavita"}\n\n')
guest_set = {"Sarika", "Divya","Kavita"}
input("Want to go to next task? (Press Enter to continue)")


# Finding the guest:
print_large("Finding the guest:")
print("Her absent-minded aunt kept asking about Divya being in the guest set.")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\n"Divya" in guest_set\n\n')
is_present = "Divya" in guest_set
input("Want to go to next task? (Press Enter to continue)")


# Adding Guests:
print_large("Adding Guests:")
print("Her mother asked her to add her friend 'Sarita' to the guest_set.")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nguest_set.add("Sarita")\n\n')
guest_set.add("Sarita")
input("Want to go to next task? (Press Enter to continue)")


# Length:
print_large("Length:")
print("She wondered how many guests are there")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nlen(guest_set)\n\n')
len(guest_set)
input("Want to go to next task? (Press Enter to continue)")


# Extending:
print_large("Extending->Modifies original set which is written first:")
guest_set_father = {"Ram","Shyam"}
print(f"Her father also created a guest_set_father : {guest_set_father} So, she decided to update her set.")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nguest_set.update(guest_set_father)\n\n')
guest_set.update(guest_set_father)
input("Want to go to next task? (Press Enter to continue)")


# Concatenation:
print_large("Concatenation->Results in a new set:")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\ncombined_guest_set = guest_set.union(guest_set_father)\n\n')
combined_guest_set = guest_set.union(guest_set_father)
input("Want to go to next task? (Press Enter to continue)")


# Removing an element:
print_large("Removing an element:")
print("She decided to not invite Sarika and update set in place.")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nguest_set.remove("Sarika")\n\n')
guest_set.remove("Sarika")
input("Want to go to next task? (Press Enter to continue)")


# Clearing all elements:
print_large("Clearing all elements:")
print("Post the wedding she decided to delete the guest set")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nguest_set.clear()\n\n')
guest_set.clear()
print_large("########End of task########\n\n\n")
# Out:
# Creation:
# Mahima started with a set {} containing her friends Sarika, Divya, Kavita
# Ready to see code? (Press Enter to continue)
#
#
# guest_set = {"Sarika", "Divya","Kavita"}
#
#
# Want to go to next task? (Press Enter to continue)
# Finding the guest:
# Her absent-minded aunt kept asking about Divya being in the guest set.
# Ready to see code? (Press Enter to continue)
#
#
# "Divya" in guest_set
#
#
# Want to go to next task? (Press Enter to continue)
# Adding Guests:
# Her mother asked her to add her friend 'Sarita' to the guest_set.
# Ready to see code? (Press Enter to continue)
#
#
# guest_set.add("Sarita")
#
#
# Want to go to next task? (Press Enter to continue)
# Length:
# She wondered how many guests are there
# Ready to see code? (Press Enter to continue)
#
#
# len(guest_set)
#
#
# Want to go to next task? (Press Enter to continue)
# Extending->Modifies original set which is written first:
# ...

# %% [markdown]
# # The Wedding Hashtag : String

# %%
# Creation:
print_large("Creation:")
print("Mahima started by creating 2 strings to store 2 wedding hashtag:")
input("Ready to see code? (Press Enter to continue)")
print_large('\n\nwedding_hashtag_1 = " #TheNotebookLoveStory "\nwedding_hashtag_2 = "#Wedlock"\n\n')
wedding_hashtag_1 = " #TheNotebookLoveStory "
wedding_hashtag_2 = "#Wedlock"
input("Want to go to next task? (Press Enter to continue)\n")

# String Stripping
print_large("String Stripping:")
print("Nishant pointed out some extra whitespace around wedding hashtag and asked Mahima to remove it")
input("Ready to see code? (Press Enter to continue)")
print_large(f"\n\nwedding_hashtag_1 = wedding_hashtag_1.strip()\n\n")
wedding_hashtag_1 = wedding_hashtag_1.strip()
input("Want to go to next task? (Press Enter to continue)\n")

# Accessing via index:
print_large("Accessing via index:")
print("While making the hashtag, she wanted to confirm that it starts with #:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nfirst_letter = wedding_hashtag_1[0]")
first_letter = wedding_hashtag_1[0]
input("Want to go to next task? (Press Enter to continue)\n")

# Checking Existence:
print_large("Checking Existence:")
print("While making the hashtag, she wanted to confirm that it has the word Love:")
input("Ready to see code? (Press Enter to continue)")
print_large('\nis_love = "Love" in wedding_hashtag_1')
is_love = "Love" in wedding_hashtag_1
input("Want to go to next task? (Press Enter to continue)\n")

# Count of Occurrence of an element:
print_large("Count of Occurrence of an element:")
print("While making the hashtag, she wanted to confirm that # isn't mistakenly repeated:")
input("Ready to see code? (Press Enter to continue)")
print_large('\ncount = wedding_hashtag_1.count("#")')
count = wedding_hashtag_1.count("#")
input("Want to go to next task? (Press Enter to continue)\n")

# Length:
print_large("Length:")
print("She also wanted to confirm the length of the hashtag for printing purpose:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nlength = len(wedding_hashtag_1)")
length = len(wedding_hashtag_1)
input("Want to go to next task? (Press Enter to continue)\n")

# Sorting
print_large("Sorting -> Creates new string as string is immutable:")
print("She also wanted to sort the hashtag to know the letters used for printing purpose:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nsorted_hashtag = sorted(wedding_hashtag_1)")
sorted_hashtag = sorted(wedding_hashtag_1)
input("Want to go to next task? (Press Enter to continue)\n")

# Slicing
print_large("Slicing -> Extracting Substrings:")
print("While designing the hoarding, she needed to extract the last two words of the hashtag:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nlast_words = wedding_hashtag_1[12:]")
last_words = wedding_hashtag_1[12:]
input("Want to go to next task? (Press Enter to continue)\n")

# Concatenation
print_large("Concatenation-> Resulting in a new string:")
invitation_location = "Banqet Hall"
print(f"She wanted to combine the invitation location : {invitation_location} and date into a single string:")
input("Ready to see code? (Press Enter to continue)")
print_large('\ninvitation_location_and_date = invitation_location + "," + "Saturday, August 12th"')
invitation_location_and_date = invitation_location + "," + "Saturday, August 12th"
input("Want to go to next task? (Press Enter to continue)\n")

# Replacing
print_large("Replacing -> generates new string as it is immutable:")
print("Nishant noticed a typo in the venue name on the invitations printed initially. Mahima used string replacement to fix it:")
input("Ready to see code? (Press Enter to continue)")
print_large('\ninvitation_location_and_date = invitation_location_and_date.replace("Banqet", "Banquet")')
invitation_location_and_date = invitation_location_and_date.replace("Banqet", "Banquet")
input("Want to go to next task? (Press Enter to continue)\n")

# Splitting
print_large("Splitting:")
task_string = "decorations, wedding_hashtag, dresses, makeup_artist"
print(f"She was asked to generate a task list from a string format {task_string}:")
input("Ready to see code? (Press Enter to continue)")
print_large('\ntask_string = task_string.split(", ")')
task_list = task_string.split(", ")
input("Want to go to next task? (Press Enter to continue)\n")

# String Joining
print_large("String Joining:")
print("She misplaced her task_string and wanted to get it back through the list she had just created.")
input("Ready to see code? (Press Enter to continue)")
print_large(f'\ntask_string = ",".join(task_list)')
task_string = ",".join(task_list)
input("Want to go to next task? (Press Enter to continue)\n")

# String Substitution/Replacement
print_large("String Substitution/Replacement:")
print("Mahima wanted to personalize wedding hashtag with the bride and groom name:")
input("Ready to see code? (Press Enter to continue)")
bride_name = "Emma"
groom_name = "Jack"
print_large(f'\npersonalized_hashtag = wedding_hashtag_1.replace("Notebook", bride_name+groom_name)')
personalized_hashtag = wedding_hashtag_1.replace("Notebook", bride_name + groom_name)
input("Want to go to next task? (Press Enter to continue)\n")

# String Formatting
print_large("String Formatting:")
print("To make the invitation message to some of the guests more elegant, Mahima used string formatting:")
elite_guest_name = "Mr. Goyal"
input("Ready to see code? (Press Enter to continue)")
print_large('\ninvitation_message_formatted = f"Dear {elite_guest_name}, you are cordially invited to the wedding."')
invitation_message_formatted = f"Dear {elite_guest_name}, you are cordially invited to the wedding."
input("Want to go to next task? (Press Enter to continue)\n")

# String Case Conversion
print_large("String Case Conversion:")
print("She wanted to convert the elite guest names to uppercase for a more formal look:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nelite_guest_uppercase = elite_guest_name.upper()")
elite_guest_uppercase = elite_guest_name.upper()
input("Want to go to next task? (Press Enter to continue)\n")

# String Validation
print_large("String Validation:")
print("She wanted to check if the wedding_hashtag has only alphabets:")
input("Ready to see code? (Press Enter to continue)")
print_large("\nis_num_special_char = wedding_hashtag_1.isalpha()")
is_num_special_char = wedding_hashtag_1.isalpha()
print_large("\n\n#########End of task#########\n")
# Out:
# Creation:
# Mahima started by creating 2 strings to store 2 wedding hashtag:
# Ready to see code? (Press Enter to continue)
#
#
# wedding_hashtag_1 = " #TheNotebookLoveStory "
# wedding_hashtag_2 = "#Wedlock"
#
#
# Want to go to next task? (Press Enter to continue)
#
# String Stripping:
# Nishant pointed out some extra whitespace around wedding hashtag and asked Mahima to remove it
# Ready to see code? (Press Enter to continue)
#
#
# wedding_hashtag_1 = wedding_hashtag_1.strip()
#
#
# Want to go to next task? (Press Enter to continue)
#
# Accessing via index:
# While making the hashtag, she wanted to confirm that it starts with #:
# Ready to see code? (Press Enter to continue)
#
# first_letter = wedding_hashtag_1[0]
# Want to go to next task? (Press Enter to continue)
#
# Checking Existence:
# While making the hashtag, she wanted to confirm that it has the word Love:
# Ready to see code? (Press Enter to continue)
#
# is_love = "Love" in wedding_hashtag_1
# ...
